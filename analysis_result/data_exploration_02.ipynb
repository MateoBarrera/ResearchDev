# %%
# Total alternatives 56
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# Read the Excel file into a pandas DataFrame
df = pd.read_excel("../lista_de_resultados_CI_56a_16-07-2024.xlsx")
df.rename(columns={"Unnamed: 0":"Alternative"}, inplace=True)
df.head()
# Out:
#    Alternative  Scenario 1  Scenario 2  Scenario 3  Scenario 4  Scenario 5  \
# 0            0    0.433742    0.564537    0.568099    0.564401    0.589339
# 1            1    0.425358    0.556617    0.560353    0.556587    0.581420
# 2            2    0.413934    0.560796    0.563714    0.558932    0.592450
# 3            3    0.408209    0.507008    0.509292    0.507082    0.523340
# 4            4    0.417296    0.545435    0.549381    0.545661    0.569317
#
#    Scenario 6  Scenario 7  Scenario 8  Scenario 9  ...  Scenario 20  \
# 0    0.588559    0.564322    0.567826    0.339100  ...     0.356854
# 1    0.580508    0.555985    0.559436    0.330082  ...     0.342106
# 2    0.591729    0.559550    0.564396    0.284432  ...     0.343518
# 3    0.523153    0.508514    0.510875    0.339464  ...     0.342739
# 4    0.568242    0.544313    0.547542    0.326085  ...     0.329790
#
#    Scenario 21  Scenario 22  Scenario 23  Scenario 24  Scenario 25  \
# 0     0.386923     0.349788     0.328671     0.361755     0.365507
# 1     0.372615     0.332372     0.315590     0.350197     0.353917
# 2     0.392982     0.349856     0.307851     0.343012     0.347916
# 3     0.365512     0.340915     0.339110     0.362826     0.365431
# 4     0.357472     0.314768     0.302994     0.338475     0.342004
#
#    Scenario 26  Scenario 27  Scenario 28  Scenario 29
# 0     0.286319     0.270513     0.303220     0.277669
# 1     0.271486     0.254134     0.287052     0.259336
# 2     0.257044     0.239423     0.289234     0.260973
# 3     0.312056     0.302309     0.322565     0.306553
# 4     0.258361     0.239768     0.270496     0.240949
#
# [5 rows x 30 columns]

# %%
df_dummy = df.copy()
df_dummy.drop(columns=["Alternative"], inplace=True)
# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(df_dummy.corr(), annot=True)

# Display the heatmap
plt.show()

# %%
# Read the Excel file into a pandas DataFrame
df_categorical = pd.read_excel("../lista_de_resultados_56a_16-07-2024.xlsx")
df_categorical.rename(columns={"Unnamed: 0": "Alternative"}, inplace=True)
df_categorical.head()
# Out:
#    Alternative  Scenario 1  Scenario 2  Scenario 3  Scenario 4  Scenario 5  \
# 0            0          24          10           9           9          11
# 1            1          27          14          13          14          13
# 2            2          34          12          11          12          10
# 3            3          38          33          32          33          33
# 4            4          31          19          18          18          19
#
#    Scenario 6  Scenario 7  Scenario 8  Scenario 9  ...  Scenario 20  \
# 0          11          10           9          26  ...           31
# 1          13          14          14          27  ...           40
# 2          10          12          11          46  ...           38
# 3          33          33          33          25  ...           39
# 4          19          18          19          31  ...           43
#
#    Scenario 21  Scenario 22  Scenario 23  Scenario 24  Scenario 25  \
# 0           32           35           26           24           23
# 1           38           42           31           28           29
# 2           31           34           34           33           33
# 3           40           39           22           23           24
# 4           43           47           37           37           37
#
#    Scenario 26  Scenario 27  Scenario 28  Scenario 29
# 0           27           28           28           30
# 1           32           33           34           36
# 2           37           39           32           35
# 3           21           21           22           21
# 4           36           38           42           44
#
# [5 rows x 30 columns]

# %%
df_dummy_categorical = df_categorical.copy()
df_dummy_categorical.drop(columns=["Alternative"], inplace=True)
# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
#sns.heatmap(df_dummy_categorical.corr(method='kendall'), annot=True)
ax = sns.heatmap(df_dummy_categorical.corr(), annot=True)
ax.set(xlabel="", ylabel="")

# Display the heatmap
plt.show()

# %%
df_environmental_ci = df_dummy[
    [
        "Scenario 16",
        "Scenario 17",
        "Scenario 18",
        "Scenario 19",
        "Scenario 20",
        "Scenario 21",
        "Scenario 22",
    ]
].copy()

df_environmental_cg = df_dummy_categorical[
    [
        "Scenario 16",
        "Scenario 17",
        "Scenario 18",
        "Scenario 19",
        "Scenario 20",
        "Scenario 21",
        "Scenario 22",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Environmental dimension")
sns.heatmap(df_environmental_ci.corr(), annot=True, ax=ax1)
sns.heatmap(
    df_environmental_cg.corr(), annot=True, ax=ax2
)
# Display the heatmap
plt.show()

# %%
df_technical_ci = df_dummy[
    [
        "Scenario 2",
        "Scenario 3",
        "Scenario 4",
        "Scenario 5",
        "Scenario 6",
        "Scenario 7",
        "Scenario 8",
    ]
].copy()

df_technical_cg = df_dummy_categorical[
    [
        "Scenario 2",
        "Scenario 3",
        "Scenario 4",
        "Scenario 5",
        "Scenario 6",
        "Scenario 7",
        "Scenario 8",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Technical dimension")
sns.heatmap(df_technical_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_technical_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
plt.show()

# %%
df_economical_ci = df_dummy[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()

df_economical_cg = df_dummy_categorical[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Economical dimension")
sns.heatmap(df_economical_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_economical_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
plt.show()

# %%
df_social_ci = df_dummy[
    [
        "Scenario 23",
        "Scenario 24",
        "Scenario 25",
        "Scenario 26",
        "Scenario 27",
        "Scenario 28",
        "Scenario 29",
    ]
].copy()

df_social_cg = df_dummy_categorical[
    [
        "Scenario 23",
        "Scenario 24",
        "Scenario 25",
        "Scenario 26",
        "Scenario 27",
        "Scenario 28",
        "Scenario 29",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Social dimension")
sns.heatmap(df_social_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_social_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
# plt.show()
# Out:
# <Axes: >
