# %%
# Total alternatives 1680
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# Read the Excel file into a pandas DataFrame
df = pd.read_excel("../lista_de_resultados_CI_1680a_16-07-2024.xlsx")
df.rename(columns={"Unnamed: 0":"Alternative"}, inplace=True)
df.head()
# Out:
#    Alternative  Scenario 1  Scenario 2  Scenario 3  Scenario 4  Scenario 5  \
# 0            0    0.427447    0.564071    0.567908    0.563836    0.591030
# 1            1    0.425720    0.565469    0.569365    0.565181    0.593214
# 2            2    0.412403    0.560118    0.563698    0.559070    0.591221
# 3            3    0.379925    0.507319    0.510460    0.506378    0.534910
# 4            4    0.423898    0.562849    0.566772    0.562607    0.590320
#
#    Scenario 6  Scenario 7  Scenario 8  Scenario 9  ...  Scenario 20  \
# 0    0.590087    0.563363    0.567148    0.328466  ...     0.347673
# 1    0.592252    0.564742    0.568642    0.322910  ...     0.342103
# 2    0.590374    0.559416    0.563966    0.294107  ...     0.333377
# 3    0.534242    0.506924    0.511007    0.290913  ...     0.331498
# 4    0.589325    0.562003    0.565847    0.321844  ...     0.338995
#
#    Scenario 21  Scenario 22  Scenario 23  Scenario 24  Scenario 25  \
# 0     0.380065     0.340400     0.318580     0.352688     0.356560
# 1     0.376915     0.335695     0.315358     0.350458     0.354436
# 2     0.377350     0.335905     0.306886     0.341707     0.346181
# 3     0.360391     0.331032     0.293673     0.319032     0.322692
# 4     0.373453     0.331558     0.312457     0.347819     0.351760
#
#    Scenario 26  Scenario 27  Scenario 28  Scenario 29
# 0     0.274560     0.257891     0.292315     0.265513
# 1     0.269807     0.252337     0.288633     0.260719
# 2     0.259340     0.242273     0.285795     0.258429
# 3     0.259630     0.249304     0.279454     0.261417
# 4     0.266687     0.248879     0.284836     0.256454
#
# [5 rows x 30 columns]

# %%
df_dummy = df.copy()
df_dummy.drop(columns=["Alternative"], inplace=True)
# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(df_dummy.corr(), annot=True)

# Display the heatmap
plt.show()

# %%
# Read the Excel file into a pandas DataFrame
df_categorical = pd.read_excel("../lista_de_resultados_1680a_16-07-2024.xlsx")
df_categorical.rename(columns={"Unnamed: 0": "Alternative"}, inplace=True)
df_categorical.head()
# Out:
#    Alternative  Scenario 1  Scenario 2  Scenario 3  Scenario 4  Scenario 5  \
# 0            0         627         110         101          97         144
# 1            1         645         100          85          87         121
# 2            2         799         151         144         144         142
# 3            3        1256         936         914         952         763
# 4            4         670         120         111         105         152
#
#    Scenario 6  Scenario 7  Scenario 8  Scenario 9  ...  Scenario 20  \
# 0         145          95          97         785  ...          949
# 1         122          79          81         826  ...         1008
# 2         142         124         123        1077  ...         1111
# 3         765         961         926        1111  ...         1130
# 4         151         105         104         838  ...         1043
#
#    Scenario 21  Scenario 22  Scenario 23  Scenario 24  Scenario 25  \
# 0          927         1029          805          744          742
# 1          964         1087          828          758          756
# 2          960         1083          885          822          819
# 3         1180         1147         1030         1113         1121
# 4         1013         1140          845          779          770
#
#    Scenario 26  Scenario 27  Scenario 28  Scenario 29
# 0          867          892          868          916
# 1          889          922          896          960
# 2          964         1000          924          972
# 3          963          943          986          951
# 4          909          948          934          994
#
# [5 rows x 30 columns]

# %%
df_dummy_categorical = df_categorical.copy()
df_dummy_categorical.drop(columns=["Alternative"], inplace=True)
# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
#sns.heatmap(df_dummy_categorical.corr(method='kendall'), annot=True)
ax = sns.heatmap(df_dummy_categorical.corr(), annot=True)
ax.set(xlabel="", ylabel="")

# Display the heatmap
plt.show()

# %%
df_environmental_ci = df_dummy[
    [
        "Scenario 16",
        "Scenario 17",
        "Scenario 18",
        "Scenario 19",
        "Scenario 20",
        "Scenario 21",
        "Scenario 22",
    ]
].copy()

df_environmental_cg = df_dummy_categorical[
    [
        "Scenario 16",
        "Scenario 17",
        "Scenario 18",
        "Scenario 19",
        "Scenario 20",
        "Scenario 21",
        "Scenario 22",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Environmental dimension")
sns.heatmap(df_environmental_ci.corr(), annot=True, ax=ax1)
sns.heatmap(
    df_environmental_cg.corr(), annot=True, ax=ax2
)
# Display the heatmap
plt.show()

# %%
df_technical_ci = df_dummy[
    [
        "Scenario 2",
        "Scenario 3",
        "Scenario 4",
        "Scenario 5",
        "Scenario 6",
        "Scenario 7",
        "Scenario 8",
    ]
].copy()

df_technical_cg = df_dummy_categorical[
    [
        "Scenario 2",
        "Scenario 3",
        "Scenario 4",
        "Scenario 5",
        "Scenario 6",
        "Scenario 7",
        "Scenario 8",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Technical dimension")
sns.heatmap(df_technical_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_technical_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
plt.show()

# %%
df_economical_ci = df_dummy[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()

df_economical_cg = df_dummy_categorical[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Economical dimension")
sns.heatmap(df_economical_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_economical_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
plt.show()

# %%
df_social_ci = df_dummy[
    [
        "Scenario 23",
        "Scenario 24",
        "Scenario 25",
        "Scenario 26",
        "Scenario 27",
        "Scenario 28",
        "Scenario 29",
    ]
].copy()

df_social_cg = df_dummy_categorical[
    [
        "Scenario 23",
        "Scenario 24",
        "Scenario 25",
        "Scenario 26",
        "Scenario 27",
        "Scenario 28",
        "Scenario 29",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Social dimension")
sns.heatmap(df_social_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_social_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
# plt.show()
# Out:
# <Axes: >
