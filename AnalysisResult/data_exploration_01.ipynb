# %%
# Total alternatives 23
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# Read the Excel file into a pandas DataFrame
df = pd.read_excel("../lista_de_resultados_CI_23a_16-07-2024.xlsx")
df.rename(columns={"Unnamed: 0":"Alternative"}, inplace=True)
df.head()
# Out:
#    Alternative  Scenario 1  Scenario 2  Scenario 3  Scenario 4  Scenario 5  \
# 0            0    0.548754    0.615021    0.590822    0.592151    0.627976
# 1            1    0.522241    0.588019    0.567222    0.569399    0.595767
# 2            2    0.480473    0.585519    0.564814    0.565514    0.602552
# 3            3    0.492744    0.502185    0.485818    0.487643    0.503861
# 4            4    0.481596    0.606120    0.589321    0.588627    0.628478
#
#    Scenario 6  Scenario 7  Scenario 8  Scenario 9  ...  Scenario 20  \
# 0    0.640552    0.635700    0.646734    0.370088  ...     0.512787
# 1    0.606771    0.609335    0.617885    0.354092  ...     0.413783
# 2    0.614165    0.606429    0.617213    0.286186  ...     0.389318
# 3    0.511343    0.514827    0.520208    0.372156  ...     0.481604
# 4    0.638302    0.622518    0.632985    0.300489  ...     0.405008
#
#    Scenario 21  Scenario 22  Scenario 23  Scenario 24  Scenario 25  \
# 0     0.786519     0.695922     0.689916     0.740060     0.765500
# 1     0.633307     0.580376     0.672223     0.721732     0.742030
# 2     0.596156     0.531053     0.567963     0.621679     0.640100
# 3     0.647119     0.617283     0.627743     0.643974     0.654681
# 4     0.575675     0.508122     0.490262     0.541723     0.555824
#
#    Scenario 26  Scenario 27  Scenario 28  Scenario 29
# 0     0.621376     0.612907     0.834913     0.753053
# 1     0.613484     0.603321     0.784804     0.721069
# 2     0.500319     0.486987     0.642123     0.588529
# 3     0.592869     0.590296     0.713579     0.686052
# 4     0.418556     0.401401     0.525359     0.479059
#
# [5 rows x 30 columns]

# %%
df_dummy = df.copy()
df_dummy.drop(columns=["Alternative"], inplace=True)
# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(df_dummy.corr(), annot=True)

# Display the heatmap
plt.show()

# %%
# Read the Excel file into a pandas DataFrame
df_categorical = pd.read_excel("../lista_de_resultados_23a_16-07-2024.xlsx")
df_categorical.rename(columns={"Unnamed: 0": "Alternative"}, inplace=True)
df_categorical.head()
# Out:
#    Alternative  Scenario 1  Scenario 2  Scenario 3  Scenario 4  Scenario 5  \
# 0            0           3           1           2           2           3
# 1            1           5           4           7           7           7
# 2            2          13           5           8           8           5
# 3            3           8          18          18          18          18
# 4            4          12           3           3           3           2
#
#    Scenario 6  Scenario 7  Scenario 8  Scenario 9  ...  Scenario 20  \
# 0           1           1           1           9  ...            5
# 1           6           3           3          12  ...           12
# 2           4           5           4          21  ...           16
# 3          18          18          18           8  ...            7
# 4           2           2           2          18  ...           15
#
#    Scenario 21  Scenario 22  Scenario 23  Scenario 24  Scenario 25  \
# 0            1            1            1            1            1
# 1            4            6            2            2            2
# 2            7           10           10            8            6
# 3            3            3            6            5            5
# 4            9           12           14           12           12
#
#    Scenario 26  Scenario 27  Scenario 28  Scenario 29
# 0            4            5            1            1
# 1            6            6            2            3
# 2           10           11            9           10
# 3            8            7            5            4
# 4           17           17           13           14
#
# [5 rows x 30 columns]

# %%
df_dummy_categorical = df_categorical.copy()
df_dummy_categorical.drop(columns=["Alternative"], inplace=True)
# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
#sns.heatmap(df_dummy_categorical.corr(method='kendall'), annot=True)
ax = sns.heatmap(df_dummy_categorical.corr(), annot=True)
ax.set(xlabel="", ylabel="")

# Display the heatmap
plt.show()

# %%
df_environmental_ci = df_dummy[
    [
        "Scenario 16",
        "Scenario 17",
        "Scenario 18",
        "Scenario 19",
        "Scenario 20",
        "Scenario 21",
        "Scenario 22",
    ]
].copy()

df_environmental_cg = df_dummy_categorical[
    [
        "Scenario 16",
        "Scenario 17",
        "Scenario 18",
        "Scenario 19",
        "Scenario 20",
        "Scenario 21",
        "Scenario 22",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Environmental dimension")
sns.heatmap(df_environmental_ci.corr(), annot=True, ax=ax1)
sns.heatmap(
    df_environmental_cg.corr(), annot=True, ax=ax2
)
# Display the heatmap
plt.show()

# %%
df_technical_ci = df_dummy[
    [
        "Scenario 2",
        "Scenario 3",
        "Scenario 4",
        "Scenario 5",
        "Scenario 6",
        "Scenario 7",
        "Scenario 8",
    ]
].copy()

df_technical_cg = df_dummy_categorical[
    [
        "Scenario 2",
        "Scenario 3",
        "Scenario 4",
        "Scenario 5",
        "Scenario 6",
        "Scenario 7",
        "Scenario 8",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Technical dimension")
sns.heatmap(df_technical_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_technical_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
plt.show()

# %%
df_economical_ci = df_dummy[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()

df_economical_cg = df_dummy_categorical[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Economical dimension")
sns.heatmap(df_economical_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_economical_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
plt.show()

# %%
df_social_ci = df_dummy[
    [
        "Scenario 23",
        "Scenario 24",
        "Scenario 25",
        "Scenario 26",
        "Scenario 27",
        "Scenario 28",
        "Scenario 29",
    ]
].copy()

df_social_cg = df_dummy_categorical[
    [
        "Scenario 23",
        "Scenario 24",
        "Scenario 25",
        "Scenario 26",
        "Scenario 27",
        "Scenario 28",
        "Scenario 29",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Social dimension")
sns.heatmap(df_social_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_social_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
# plt.show()
# Out:
# <Axes: >
