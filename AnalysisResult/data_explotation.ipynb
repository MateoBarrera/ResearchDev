# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# Read the Excel file into a pandas DataFrame
df = pd.read_excel("../lista_de_resultados_CI.xlsx")
df.rename(columns={"Unnamed: 0":"Alternative"}, inplace=True)
df.head()
# Out:
#    Alternative  Scenario 1  Scenario 2  Scenario 3  Scenario 4  Scenario 5  \
# 0            0    0.434331    0.581381    0.585638    0.581206    0.611785
# 1            1    0.415733    0.558709    0.563447    0.559032    0.587373
# 2            2    0.398339    0.558393    0.561563    0.555901    0.596036
# 3            3    0.396818    0.479689    0.482021    0.480344    0.492110
# 4            4    0.423147    0.583785    0.586909    0.580505    0.624966
#
#    Scenario 6  Scenario 7  Scenario 8  Scenario 9  ...  Scenario 20  \
# 0    0.610849    0.581292    0.585524    0.334723  ...     0.354350
# 1    0.586025    0.557318    0.561111    0.320231  ...     0.320782
# 2    0.595143    0.556367    0.562093    0.261153  ...     0.326859
# 3    0.491797    0.480960    0.482579    0.342045  ...     0.324953
# 4    0.623766    0.579850    0.586148    0.287208  ...     0.381673
#
#    Scenario 21  Scenario 22  Scenario 23  Scenario 24  Scenario 25  \
# 0     0.386103     0.348192     0.326270     0.360051     0.363960
# 1     0.349633     0.304185     0.295266     0.332390     0.336016
# 2     0.380095     0.332822     0.284291     0.321540     0.326750
# 3     0.342681     0.320305     0.337402     0.358473     0.360302
# 4     0.429360     0.382272     0.299636     0.335734     0.341358
#
#    Scenario 26  Scenario 27  Scenario 28  Scenario 29
# 0     0.283367     0.267635     0.301188     0.275651
# 1     0.249078     0.229503     0.260747     0.229690
# 2     0.229209     0.209508     0.264044     0.233108
# 3     0.315971     0.307141     0.320231     0.306423
# 4     0.242200     0.223444     0.280813     0.250436
#
# [5 rows x 30 columns]

# %%
df_dummy = df.copy()
df_dummy.drop(columns=["Alternative"], inplace=True)
# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(df_dummy.corr(), annot=True)

# Display the heatmap
plt.show()

# %%
# Read the Excel file into a pandas DataFrame
df_categorical = pd.read_excel("../lista_de_resultados.xlsx")
df_categorical.rename(columns={"Unnamed: 0": "Alternative"}, inplace=True)
df_categorical.head()
# Out:
#    Alternative  Scenario 1  Scenario 2  Scenario 3  Scenario 4  Scenario 5  \
# 0            0          10           3           3           2           3
# 1            1          14           8           7           8           7
# 2            2          17           9           8           9           5
# 3            3          19          18          18          18          19
# 4            4          13           2           2           3           2
#
#    Scenario 6  Scenario 7  Scenario 8  Scenario 9  ...  Scenario 20  \
# 0           3           2           3          12  ...           15
# 1           7           8           9          16  ...           20
# 2           5           9           8          21  ...           18
# 3          19          18          18          11  ...           19
# 4           2           3           2          18  ...            9
#
#    Scenario 21  Scenario 22  Scenario 23  Scenario 24  Scenario 25  \
# 0           13           16           13           12           11
# 1           20           21           18           18           18
# 2           16           18           19           19           19
# 3           21           19           11           13           13
# 4            8            9           17           17           15
#
#    Scenario 26  Scenario 27  Scenario 28  Scenario 29
# 0           15           15           13           15
# 1           17           17           20           20
# 2           19           19           18           18
# 3           10            8           11           10
# 4           18           18           17           17
#
# [5 rows x 30 columns]

# %%
df_dummy_categorical = df_categorical.copy()
df_dummy_categorical.drop(columns=["Alternative"], inplace=True)
# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(df_dummy_categorical.corr(method='kendall'), annot=True)

# Display the heatmap
plt.show()

# %%
df_technical_cg = df_dummy_categorical[['Scenario 2', 'Scenario 3', 'Scenario 4', 'Scenario 5', 'Scenario 6', 'Scenario 7', 'Scenario 8']].copy()

plt.figure(figsize=(10, 8))
sns.heatmap(df_technical_cg.corr(), annot=True)

# Display the heatmap
plt.show()

# %%
df_economy_cg = df_dummy_categorical[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()

plt.figure(figsize=(10, 8))
sns.heatmap(df_economy_cg.corr(), annot=True)

# Display the heatmap
plt.show()

# %%
df_environmental_cg = df_dummy_categorical[
    [
        "Scenario 16",
        "Scenario 17",
        "Scenario 18",
        "Scenario 19",
        "Scenario 20",
        "Scenario 21",
        "Scenario 22",
    ]
].copy()

plt.figure(figsize=(10, 8))
sns.heatmap(df_environmental_cg.corr(), annot=True)

# Display the heatmap
plt.show()

# %%
df_social_cg = df_dummy_categorical[
    [
        "Scenario 23",
        "Scenario 24",
        "Scenario 25",
        "Scenario 26",
        "Scenario 27",
        "Scenario 28",
        "Scenario 29",
    ]
].copy()

plt.figure(figsize=(10, 8))
sns.heatmap(df_social_cg.corr(), annot=True)

# Display the heatmap
plt.show()

# %%
df_technical_ci = df_dummy[
    [
        "Scenario 2",
        "Scenario 3",
        "Scenario 4",
        "Scenario 5",
        "Scenario 6",
        "Scenario 7",
        "Scenario 8",
    ]
].copy()

plt.figure(figsize=(10, 8))
sns.heatmap(df_technical_ci.corr(), annot=True)

# Display the heatmap
plt.show()

# %%
df_economy_ci = df_dummy[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()

plt.figure(figsize=(10, 8))
sns.heatmap(df_economy_ci.corr(), annot=True)

# Display the heatmap
plt.show()

# %%
df_environmental_ci = df_dummy[
    [
        "Scenario 16",
        "Scenario 17",
        "Scenario 18",
        "Scenario 19",
        "Scenario 20",
        "Scenario 21",
        "Scenario 22",
    ]
].copy()

df_environmental_cg = df_dummy_categorical[
    [
        "Scenario 16",
        "Scenario 17",
        "Scenario 18",
        "Scenario 19",
        "Scenario 20",
        "Scenario 21",
        "Scenario 22",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
sns.heatmap(df_environmental_ci.corr(), annot=True, ax=ax1)
sns.heatmap(
    df_environmental_cg.corr(), annot=True, ax=ax2
)
# Display the heatmap
plt.show()

# %%
df_technical_ci = df_dummy[
    [
        "Scenario 2",
        "Scenario 3",
        "Scenario 4",
        "Scenario 5",
        "Scenario 6",
        "Scenario 7",
        "Scenario 8",
    ]
].copy()

df_technical_cg = df_dummy_categorical[
    [
        "Scenario 2",
        "Scenario 3",
        "Scenario 4",
        "Scenario 5",
        "Scenario 6",
        "Scenario 7",
        "Scenario 8",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
sns.heatmap(df_technical_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_technical_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
plt.show()

# %%
df_economical_ci = df_dummy[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()

df_economical_cg = df_dummy_categorical[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
sns.heatmap(df_economical_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_economical_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
plt.show()

# %%
df_social_ci = df_dummy[
    [
        "Scenario 23",
        "Scenario 24",
        "Scenario 25",
        "Scenario 26",
        "Scenario 27",
        "Scenario 28",
        "Scenario 29",
    ]
].copy()

df_social_cg = df_dummy_categorical[
    [
        "Scenario 23",
        "Scenario 24",
        "Scenario 25",
        "Scenario 26",
        "Scenario 27",
        "Scenario 28",
        "Scenario 29",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
sns.heatmap(df_social_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_social_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
#plt.show()
# Out:
# <Axes: >
