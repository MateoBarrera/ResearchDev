# %%
# Total alternatives 256
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# Read the Excel file into a pandas DataFrame
df = pd.read_excel("../lista_de_resultados_CI_256a_16-07-2024.xlsx")
df.rename(columns={"Unnamed: 0":"Alternative"}, inplace=True)
df.head()
# Out:
#    Alternative  Scenario 1  Scenario 2  Scenario 3  Scenario 4  Scenario 5  \
# 0            0    0.432228    0.559632    0.563008    0.559437    0.583470
# 1            1    0.428168    0.557745    0.561200    0.557544    0.582025
# 2            2    0.416747    0.554513    0.557551    0.553359    0.582399
# 3            3    0.392745    0.506932    0.509441    0.506283    0.528888
# 4            4    0.424483    0.552928    0.556500    0.552849    0.576882
#
#    Scenario 6  Scenario 7  Scenario 8  Scenario 9  ...  Scenario 20  \
# 0    0.582734    0.559389    0.562784    0.337722  ...     0.357321
# 1    0.581241    0.557365    0.560812    0.330706  ...     0.348571
# 2    0.581716    0.553854    0.558039    0.301127  ...     0.345200
# 3    0.528549    0.507521    0.510833    0.309809  ...     0.340156
# 4    0.576013    0.552293    0.555649    0.329010  ...     0.342536
#
#    Scenario 21  Scenario 22  Scenario 23  Scenario 24  Scenario 25  \
# 0     0.387699     0.350975     0.328741     0.361441     0.365199
# 1     0.380811     0.342025     0.322097     0.356010     0.359836
# 2     0.387705     0.348112     0.314704     0.348281     0.352731
# 3     0.367374     0.340158     0.312826     0.337810     0.341212
# 4     0.373547     0.333537     0.315941     0.350333     0.354067
#
#    Scenario 26  Scenario 27  Scenario 28  Scenario 29
# 0     0.286523     0.270873     0.304006     0.278685
# 1     0.278204     0.261497     0.296060     0.269268
# 2     0.268083     0.251789     0.295095     0.268721
# 3     0.280376     0.270168     0.298206     0.280607
# 4     0.271774     0.254462     0.287959     0.260321
#
# [5 rows x 30 columns]

# %%
df_dummy = df.copy()
df_dummy.drop(columns=["Alternative"], inplace=True)
# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(df_dummy.corr(), annot=True)

# Display the heatmap
plt.show()

# %%
# Read the Excel file into a pandas DataFrame
df_categorical = pd.read_excel("../lista_de_resultados_256a_16-07-2024.xlsx")
df_categorical.rename(columns={"Unnamed: 0": "Alternative"}, inplace=True)
df_categorical.head()
# Out:
#    Alternative  Scenario 1  Scenario 2  Scenario 3  Scenario 4  Scenario 5  \
# 0            0         106          27          26          26          33
# 1            1         112          31          29          28          37
# 2            2         137          38          33          36          36
# 3            3         194         145         141         146         123
# 4            4         121          43          37          37          46
#
#    Scenario 6  Scenario 7  Scenario 8  Scenario 9  ...  Scenario 20  \
# 0          33          26          26         131  ...          149
# 1          37          28          29         139  ...          164
# 2          36          37          34         181  ...          172
# 3         124         145         141         170  ...          183
# 4          46          39          42         141  ...          180
#
#    Scenario 21  Scenario 22  Scenario 23  Scenario 24  Scenario 25  \
# 0          147          161          133          121          119
# 1          161          180          141          129          128
# 2          146          170          148          141          140
# 3          184          186          154          163          167
# 4          172          195          146          137          136
#
#    Scenario 26  Scenario 27  Scenario 28  Scenario 29
# 0          136          141          140          146
# 1          146          151          150          158
# 2          160          165          152          159
# 3          144          143          147          143
# 4          154          160          163          171
#
# [5 rows x 30 columns]

# %%
df_dummy_categorical = df_categorical.copy()
df_dummy_categorical.drop(columns=["Alternative"], inplace=True)
# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
#sns.heatmap(df_dummy_categorical.corr(method='kendall'), annot=True)
ax = sns.heatmap(df_dummy_categorical.corr(), annot=True)
ax.set(xlabel="", ylabel="")

# Display the heatmap
plt.show()

# %%
df_environmental_ci = df_dummy[
    [
        "Scenario 16",
        "Scenario 17",
        "Scenario 18",
        "Scenario 19",
        "Scenario 20",
        "Scenario 21",
        "Scenario 22",
    ]
].copy()

df_environmental_cg = df_dummy_categorical[
    [
        "Scenario 16",
        "Scenario 17",
        "Scenario 18",
        "Scenario 19",
        "Scenario 20",
        "Scenario 21",
        "Scenario 22",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Environmental dimension")
sns.heatmap(df_environmental_ci.corr(), annot=True, ax=ax1)
sns.heatmap(
    df_environmental_cg.corr(), annot=True, ax=ax2
)
# Display the heatmap
plt.show()

# %%
df_technical_ci = df_dummy[
    [
        "Scenario 2",
        "Scenario 3",
        "Scenario 4",
        "Scenario 5",
        "Scenario 6",
        "Scenario 7",
        "Scenario 8",
    ]
].copy()

df_technical_cg = df_dummy_categorical[
    [
        "Scenario 2",
        "Scenario 3",
        "Scenario 4",
        "Scenario 5",
        "Scenario 6",
        "Scenario 7",
        "Scenario 8",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Technical dimension")
sns.heatmap(df_technical_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_technical_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
plt.show()

# %%
df_economical_ci = df_dummy[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()

df_economical_cg = df_dummy_categorical[
    [
        "Scenario 9",
        "Scenario 10",
        "Scenario 11",
        "Scenario 12",
        "Scenario 13",
        "Scenario 14",
        "Scenario 15",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Economical dimension")
sns.heatmap(df_economical_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_economical_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
plt.show()

# %%
df_social_ci = df_dummy[
    [
        "Scenario 23",
        "Scenario 24",
        "Scenario 25",
        "Scenario 26",
        "Scenario 27",
        "Scenario 28",
        "Scenario 29",
    ]
].copy()

df_social_cg = df_dummy_categorical[
    [
        "Scenario 23",
        "Scenario 24",
        "Scenario 25",
        "Scenario 26",
        "Scenario 27",
        "Scenario 28",
        "Scenario 29",
    ]
].copy()


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle("Correlation Heatmap\n Social dimension")
sns.heatmap(df_social_ci.corr(), annot=True, ax=ax1)
sns.heatmap(df_social_cg.corr(), annot=True, ax=ax2)
# Display the heatmap
# plt.show()
# Out:
# <Axes: >
